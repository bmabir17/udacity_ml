# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
import tensorflow as tf
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
from PIL import Image
from six.moves import range

# %%
pickle_file= 'banglaIsolated_clean.pickle'

with open(pickle_file, 'rb') as f:
    save=pickle.load(f)
    train_dataset=save['train_dataset']
    train_labels=save['train_labels']
    valid_dataset=save['valid_dataset_clean']
    valid_labels=save['valid_labels']
    test_dataset=save['test_dataset_clean']
    test_labels=save['test_labels']
    del save #hint to help gc to free up memory 
    print('training set', train_dataset.shape,train_labels.shape)
    print('validation set', valid_dataset.shape, valid_labels.shape)
    print('test set', test_dataset.shape,test_labels.shape)
# Out:
# training set (139000, 28, 28) (139000,)
# validation set (10000, 28, 28) (10000,)
# test set (10000, 28, 28) (10000,)

# %%
image_size=28
num_labels=84
num_channels=1 

def reformat(dataset, labels):
    dataset=dataset.reshape((-1,image_size,image_size,num_channels)).astype(np.float32)
    # Map 1 to [0.0,1.0,0.0....], 2 to [0.0,0.0,1.0.....]
    labels=(np.arange(num_labels) ==labels[:,None]).astype(np.float32)
    return dataset,labels
train_dataset, train_labels= reformat(train_dataset, train_labels)
valid_dataset, valid_labels=reformat(valid_dataset, valid_labels)
test_dataset, test_labels =reformat(test_dataset, test_labels)
print( 'training set', train_dataset.shape,train_labels.shape)
print('validation set', valid_dataset.shape,valid_labels.shape)
print('test set', test_dataset.shape,test_labels.shape)
# Out:
# training set (139000, 28, 28, 1) (139000, 84)
# validation set (10000, 28, 28, 1) (10000, 84)
# test set (10000, 28, 28, 1) (10000, 84)

# %%
def accuracy(predictions, labels):
    return(100.0*np.sum(np.argmax(predictions, 1)==np.argmax(labels,1))/ predictions.shape[0])

# %%
def deeper_inception_conv_net():
    
    batch_size = 50
    patch_size1 = 3
    patch_size2 = 5
    depth = 16
    depth1 = 32
    depth2 = 16
    depth3 = 8
    concat_depth = 48
    num_hidden = 128
    num_hidden2 = 64
    keep_prob = 0.5
    decay_step = 2000
    base = 0.9

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)
    
      # introduce batchnorm
      tf_train_dataset_bn=tf.contrib.layers.batch_norm(tf_train_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, num_channels, depth], stddev=0.3))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth, depth1], stddev=0.05))
      layer2_biases = tf.Variable(tf.constant(0.0, shape=[depth1]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * concat_depth, num_hidden], stddev=0.05))
      layer3_biases = tf.Variable(tf.constant(0.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_hidden2], stddev=0.01))
      layer4_biases = tf.Variable(tf.constant(0.0, shape=[num_hidden2]))
      layer5_weights = tf.Variable(tf.truncated_normal(
          [num_hidden2, num_labels], stddev=0.01))
      layer5_biases = tf.Variable(tf.constant(0.0, shape=[num_labels]))
        
      inception1x1_weights = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.25))
      inception1x1_biases = tf.Variable(tf.constant(0.0, shape=[depth2]))
      inception3x3_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, depth2, depth3], stddev=0.05))
      inception3x3_biases = tf.Variable(tf.constant(0.0, shape=[depth3]))
      inception5x5_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth2, depth3], stddev=0.08))
      inception5x5_biases = tf.Variable(tf.constant(0.0, shape=[depth3]))
    
      inception1x1_post_mxpool_wts = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.04))
      post_maxpool_biases = tf.Variable(tf.constant(0.0, shape=[depth2]))
        
      global_step = tf.Variable(0, trainable = False)  # count the number of steps taken.
      learning_rate = tf.train.exponential_decay(0.005, global_step, decay_step, base)

        
      # Model.
      def model(data, useDropout):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer1_biases)
        hidden_bn=tf.contrib.layers.batch_norm(hidden)
        conv = tf.nn.conv2d(hidden_bn, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer2_biases)
        
        inception1x1_conv = tf.nn.conv2d(hidden, inception1x1_weights, [1, 1, 1, 1], padding='SAME')
        inception1x1_relu = tf.nn.relu(inception1x1_conv + inception1x1_biases)
        
        inception3x3_conv = tf.nn.conv2d(inception1x1_relu, inception3x3_weights, [1, 1, 1, 1], padding='SAME')
        inception3x3_relu = tf.nn.relu(inception3x3_conv + inception3x3_biases)
        
        inception5x5_conv = tf.nn.conv2d(inception1x1_relu, inception5x5_weights, [1, 1, 1, 1], padding='SAME')
        inception5x5_relu = tf.nn.relu(inception5x5_conv + inception5x5_biases)
        
        inception3x3_maxpool = tf.nn.max_pool(hidden, [1, 3, 3, 1], [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.conv2d(inception3x3_maxpool, inception1x1_post_mxpool_wts, [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.relu(inception1x1_post_maxpool + post_maxpool_biases)
        
        concat_filter = tf.concat([inception1x1_relu, inception3x3_relu, inception5x5_relu, inception1x1_post_maxpool],3)
        concat_maxpooled = tf.nn.max_pool(concat_filter, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = concat_maxpooled.get_shape().as_list()
        
        reshape = tf.reshape(concat_maxpooled, [shape[0], shape[1] * shape[2] * shape[3]])
    
        if useDropout == 1:
            dropout_layer2 = tf.nn.dropout(tf.nn.relu(reshape), keep_prob)
        else:
            dropout_layer2 = tf.nn.relu(reshape)
        hidden = tf.nn.relu(tf.matmul(dropout_layer2, layer3_weights) + layer3_biases)
        
        hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
        return tf.matmul(hidden, layer5_weights) + layer5_biases

      # Training computation.
      logits = model(tf_train_dataset, 1)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))

      # Optimizer.
      optimizer = tf.train.AdamOptimizer(0.001).minimize(loss, global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(model(tf_train_dataset_bn, 0))
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 0))
      test_prediction = tf.nn.softmax(model(tf_test_dataset, 0))
        
        
        
    num_steps = 30001

    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          #print(tf.Print(layer1_weights, [layer1_weights]).eval())
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels)) 
deeper_inception_conv_net()
# Out:
# WARNING:tensorflow:From <ipython-input-16-f09902a57379>:122: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 4.429836
# Minibatch accuracy: 4.0%
# Validation accuracy: 0.7%
# Minibatch loss at step 50: 4.329522
# Minibatch accuracy: 2.0%
# Validation accuracy: 3.6%
# Minibatch loss at step 100: 3.603811
# Minibatch accuracy: 12.0%
# Validation accuracy: 11.6%
# Minibatch loss at step 150: 2.868684
# Minibatch accuracy: 12.0%
# Validation accuracy: 17.5%
# Minibatch loss at step 200: 2.937588
# Minibatch accuracy: 16.0%
# Validation accuracy: 25.8%
# Minibatch loss at step 250: 2.188837
# Minibatch accuracy: 40.0%
# Validation accuracy: 28.0%
# Minibatch loss at step 300: 1.953335
# Minibatch accuracy: 48.0%
# Validation accuracy: 36.9%
# Minibatch loss at step 350: 2.530608
# Minibatch accuracy: 36.0%
# Validation accuracy: 41.1%
# Minibatch loss at step 400: 2.191073
# Minibatch accuracy: 44.0%
# Validation accuracy: 44.3%
# Minibatch loss at step 450: 2.084200
# Minibatch accuracy: 42.0%
# Validation accuracy: 45.9%
# Minibatch loss at step 500: 2.051714
# Minibatch accuracy: 60.0%
# Validation accuracy: 50.8%
# Minibatch loss at step 550: 1.992006
# Minibatch accuracy: 42.0%
# Validation accuracy: 52.4%
# Minibatch loss at step 600: 1.901238
# Minibatch accuracy: 44.0%
# Validation accuracy: 53.5%
# Minibatch loss at step 650: 1.735548
# Minibatch accuracy: 54.0%
# Validation accuracy: 58.8%
# Minibatch loss at step 700: 1.827953
# Minibatch accuracy: 46.0%
# Validation accuracy: 59.3%
# Minibatch loss at step 750: 1.681997
# Minibatch accuracy: 60.0%
# Validation accuracy: 59.5%
# Minibatch loss at step 800: 1.478352
# Minibatch accuracy: 62.0%
# Validation accuracy: 62.8%
# Minibatch loss at step 850: 1.646054
# Minibatch accuracy: 52.0%
# Validation accuracy: 63.4%
# Minibatch loss at step 900: 1.163886
# Minibatch accuracy: 68.0%
# Validation accuracy: 64.3%
# Minibatch loss at step 950: 1.063141
# Minibatch accuracy: 72.0%
# Validation accuracy: 63.9%
# Minibatch loss at step 1000: 0.996800
# Minibatch accuracy: 72.0%
# Validation accuracy: 67.1%
# Minibatch loss at step 1050: 1.516513
# Minibatch accuracy: 62.0%
# Validation accuracy: 67.9%
# Minibatch loss at step 1100: 0.761948
# Minibatch accuracy: 74.0%
# Validation accuracy: 67.0%
# Minibatch loss at step 1150: 1.329537
# Minibatch accuracy: 58.0%
# Validation accuracy: 67.8%
# Minibatch loss at step 1200: 1.349415
# Minibatch accuracy: 60.0%
# Validation accuracy: 69.0%
# Minibatch loss at step 1250: 1.433643
# Minibatch accuracy: 66.0%
# Validation accuracy: 70.0%
# Minibatch loss at step 1300: 1.300995
# Minibatch accuracy: 52.0%
# Validation accuracy: 67.0%
# Minibatch loss at step 1350: 1.289440
# Minibatch accuracy: 60.0%
# Validation accuracy: 68.5%
# Minibatch loss at step 1400: 1.140214
# Minibatch accuracy: 68.0%
# Validation accuracy: 70.3%
# Minibatch loss at step 1450: 1.319405
# Minibatch accuracy: 68.0%
# Validation accuracy: 70.2%
# Minibatch loss at step 1500: 1.216556
# Minibatch accuracy: 58.0%
# Validation accuracy: 71.2%
# Minibatch loss at step 1550: 1.055361
# Minibatch accuracy: 72.0%
# Validation accuracy: 72.9%
# Minibatch loss at step 1600: 1.206927
# Minibatch accuracy: 76.0%
# Validation accuracy: 73.0%
# Minibatch loss at step 1650: 0.913218
# Minibatch accuracy: 72.0%
# Validation accuracy: 71.6%
# Minibatch loss at step 1700: 0.956459
# Minibatch accuracy: 70.0%
# Validation accuracy: 73.7%
# Minibatch loss at step 1750: 0.977208
# Minibatch accuracy: 70.0%
# Validation accuracy: 74.3%
# Minibatch loss at step 1800: 0.833510
# Minibatch accuracy: 74.0%
# Validation accuracy: 73.4%
# Minibatch loss at step 1850: 1.209585
# Minibatch accuracy: 58.0%
# Validation accuracy: 74.6%
# Minibatch loss at step 1900: 1.534257
# Minibatch accuracy: 66.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 1950: 0.650418
# Minibatch accuracy: 74.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 2000: 1.221097
# Minibatch accuracy: 68.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 2050: 1.284586
# Minibatch accuracy: 70.0%
# Validation accuracy: 75.7%
# Minibatch loss at step 2100: 0.942372
# Minibatch accuracy: 76.0%
# Validation accuracy: 75.5%
# Minibatch loss at step 2150: 1.147806
# Minibatch accuracy: 70.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 2200: 1.247223
# Minibatch accuracy: 70.0%
# Validation accuracy: 76.6%
# Minibatch loss at step 2250: 1.018924
# Minibatch accuracy: 70.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 2300: 0.928564
# Minibatch accuracy: 80.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 2350: 0.729392
# Minibatch accuracy: 72.0%
# Validation accuracy: 75.7%
# Minibatch loss at step 2400: 0.697010
# Minibatch accuracy: 80.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 2450: 0.996642
# Minibatch accuracy: 68.0%
# Validation accuracy: 77.1%
# Minibatch loss at step 2500: 0.740106
# Minibatch accuracy: 80.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 2550: 0.720602
# Minibatch accuracy: 84.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 2600: 0.804043
# Minibatch accuracy: 76.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 2650: 0.673734
# Minibatch accuracy: 82.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 2700: 1.006906
# Minibatch accuracy: 66.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 2750: 1.170058
# Minibatch accuracy: 70.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 2800: 0.964491
# Minibatch accuracy: 78.0%
# Validation accuracy: 78.3%
# Minibatch loss at step 2850: 1.156886
# Minibatch accuracy: 68.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 2900: 0.859525
# Minibatch accuracy: 78.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 2950: 0.814955
# Minibatch accuracy: 72.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 3000: 0.891707
# Minibatch accuracy: 70.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 3050: 0.761576
# Minibatch accuracy: 78.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 3100: 1.029212
# Minibatch accuracy: 72.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 3150: 0.744007
# Minibatch accuracy: 74.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 3200: 1.078077
# Minibatch accuracy: 64.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 3250: 0.679812
# Minibatch accuracy: 80.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 3300: 0.773101
# Minibatch accuracy: 66.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 3350: 0.783677
# Minibatch accuracy: 76.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 3400: 0.640163
# Minibatch accuracy: 76.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 3450: 0.851998
# Minibatch accuracy: 74.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 3500: 0.675139
# Minibatch accuracy: 78.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 3550: 0.675202
# Minibatch accuracy: 68.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 3600: 0.677987
# Minibatch accuracy: 72.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 3650: 1.007124
# Minibatch accuracy: 70.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 3700: 0.686617
# Minibatch accuracy: 88.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 3750: 0.531840
# Minibatch accuracy: 78.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 3800: 0.644776
# Minibatch accuracy: 80.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 3850: 0.826555
# Minibatch accuracy: 74.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 3900: 0.945536
# Minibatch accuracy: 72.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 3950: 0.790228
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 4000: 0.936705
# Minibatch accuracy: 72.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 4050: 0.853040
# Minibatch accuracy: 70.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 4100: 0.567927
# Minibatch accuracy: 68.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 4150: 0.762825
# Minibatch accuracy: 78.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 4200: 0.624408
# Minibatch accuracy: 68.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 4250: 0.777747
# Minibatch accuracy: 78.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 4300: 0.698118
# Minibatch accuracy: 70.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 4350: 1.023378
# Minibatch accuracy: 70.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 4400: 0.764890
# Minibatch accuracy: 68.0%
# Validation accuracy: 79.1%
# Minibatch loss at step 4450: 0.429944
# Minibatch accuracy: 84.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 4500: 0.629624
# Minibatch accuracy: 80.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 4550: 0.535123
# Minibatch accuracy: 66.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 4600: 0.527855
# Minibatch accuracy: 74.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 4650: 0.925717
# Minibatch accuracy: 64.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 4700: 1.118621
# Minibatch accuracy: 64.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 4750: 0.749653
# Minibatch accuracy: 74.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 4800: 0.662500
# Minibatch accuracy: 78.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 4850: 0.623930
# Minibatch accuracy: 56.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 4900: 0.882499
# Minibatch accuracy: 72.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 4950: 0.409217
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 5000: 0.641317
# Minibatch accuracy: 76.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 5050: 0.511806
# Minibatch accuracy: 80.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 5100: 0.669413
# Minibatch accuracy: 62.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 5150: 0.468313
# Minibatch accuracy: 80.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 5200: 0.665181
# Minibatch accuracy: 80.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 5250: 0.618737
# Minibatch accuracy: 76.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 5300: 1.036889
# Minibatch accuracy: 64.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 5350: 0.395623
# Minibatch accuracy: 80.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 5400: 0.863844
# Minibatch accuracy: 68.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 5450: 0.725448
# Minibatch accuracy: 78.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 5500: 0.605694
# Minibatch accuracy: 80.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 5550: 0.585126
# Minibatch accuracy: 74.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 5600: 0.507149
# Minibatch accuracy: 80.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 5650: 1.258243
# Minibatch accuracy: 66.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 5700: 0.836068
# Minibatch accuracy: 72.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 5750: 0.805343
# Minibatch accuracy: 74.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 5800: 0.905081
# Minibatch accuracy: 64.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 5850: 0.686886
# Minibatch accuracy: 74.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 5900: 0.612964
# Minibatch accuracy: 84.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 5950: 0.737980
# Minibatch accuracy: 70.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 6000: 0.563387
# Minibatch accuracy: 64.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 6050: 0.621570
# Minibatch accuracy: 78.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 6100: 0.445399
# Minibatch accuracy: 84.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 6150: 0.860220
# Minibatch accuracy: 78.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 6200: 0.664076
# Minibatch accuracy: 76.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 6250: 0.641675
# Minibatch accuracy: 78.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 6300: 0.653023
# Minibatch accuracy: 74.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 6350: 0.543936
# Minibatch accuracy: 78.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 6400: 0.733929
# Minibatch accuracy: 76.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 6450: 0.368302
# Minibatch accuracy: 86.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 6500: 0.714369
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 6550: 0.601883
# Minibatch accuracy: 76.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 6600: 0.509926
# Minibatch accuracy: 68.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 6650: 0.536302
# Minibatch accuracy: 78.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 6700: 1.163851
# Minibatch accuracy: 66.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 6750: 0.844350
# Minibatch accuracy: 62.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 6800: 1.072326
# Minibatch accuracy: 64.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 6850: 0.811291
# Minibatch accuracy: 76.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 6900: 0.540903
# Minibatch accuracy: 68.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 6950: 0.655515
# Minibatch accuracy: 72.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 7000: 0.640546
# Minibatch accuracy: 76.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 7050: 0.502997
# Minibatch accuracy: 78.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 7100: 0.555640
# Minibatch accuracy: 76.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 7150: 0.810025
# Minibatch accuracy: 70.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 7200: 0.713823
# Minibatch accuracy: 56.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 7250: 0.489402
# Minibatch accuracy: 86.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 7300: 0.483461
# Minibatch accuracy: 78.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 7350: 0.987486
# Minibatch accuracy: 60.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 7400: 0.427573
# Minibatch accuracy: 86.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 7450: 0.883212
# Minibatch accuracy: 80.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 7500: 0.615299
# Minibatch accuracy: 62.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 7550: 0.606365
# Minibatch accuracy: 76.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 7600: 0.795029
# Minibatch accuracy: 74.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 7650: 0.595632
# Minibatch accuracy: 60.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 7700: 0.626421
# Minibatch accuracy: 76.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 7750: 0.605079
# Minibatch accuracy: 66.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 7800: 0.915423
# Minibatch accuracy: 64.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 7850: 1.004518
# Minibatch accuracy: 58.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 7900: 0.833904
# Minibatch accuracy: 76.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 7950: 0.587330
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 8000: 0.648258
# Minibatch accuracy: 72.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 8050: 0.585096
# Minibatch accuracy: 66.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 8100: 0.242486
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 8150: 0.567871
# Minibatch accuracy: 86.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 8200: 0.846916
# Minibatch accuracy: 72.0%
# Validation accuracy: 85.0%
