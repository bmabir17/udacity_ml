# %%
from __future__ import print_function

import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# %%
pickle_file= 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save=pickle.load(f)
    train_dataset=save['train_dataset']
    train_labels=save['train_labels']
    valid_dataset=save['valid_dataset']
    valid_labels=save['valid_labels']
    test_dataset=save['test_dataset']
    test_labels=save['test_labels']
    del save #hint to help gc to free up memory 
    print('training set', train_dataset.shape,train_labels.shape)
    print('validation set', valid_dataset.shape, valid_labels.shape)
    print('test set', test_dataset.shape,test_labels.shape)
# Out:
# training set (200000, 28, 28) (200000,)
# validation set (10000, 28, 28) (10000,)
# test set (10000, 28, 28) (10000,)

# %%
image_size=28
num_labels=10
num_channels=1 

def reformat(dataset, labels):
    dataset=dataset.reshape((-1,image_size,image_size,num_channels)).astype(np.float32)
    # Map 1 to [0.0,1.0,0.0....], 2 to [0.0,0.0,1.0.....]
    labels=(np.arange(num_labels) ==labels[:,None]).astype(np.float32)
    return dataset,labels
train_dataset, train_labels= reformat(train_dataset, train_labels)
valid_dataset, valid_labels=reformat(valid_dataset, valid_labels)
test_dataset, test_labels =reformat(test_dataset, test_labels)
print( 'training set', train_dataset.shape,train_labels.shape)
print('validation set', valid_dataset.shape,valid_labels.shape)
print('test set', test_dataset.shape,test_labels.shape)
# Out:
# training set (200000, 28, 28, 1) (200000, 10)
# validation set (10000, 28, 28, 1) (10000, 10)
# test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return(100.0*np.sum(np.argmax(predictions, 1)==np.argmax(labels,1))/ predictions.shape[0])

# %%
batch_size=16
patch_size=5
depth=16
num_hidden=64

graph=tf.Graph()

with graph.as_default():
    
    #input data
    tf_train_dataset=tf.placeholder(tf.float32, 
                                    shape=(batch_size,image_size,image_size,num_channels))
    tf_train_labels=tf.placeholder(tf.float32, shape=(batch_size,num_labels))
    tf_valid_dataset=tf.constant(valid_dataset)
    tf_test_dataset=tf.constant(test_dataset)
    
    #variables
    layer1_weights=tf.Variable(tf.truncated_normal
                               ([patch_size,patch_size,num_channels,depth],stddev=0.1))
    layer1_biases=tf.Variable(tf.zeros([depth]))
    
    layer2_weights=tf.Variable(tf.truncated_normal
                               ([patch_size,patch_size,depth,depth],stddev=0.1))
    layer2_biases=tf.Variable(tf.constant(1.0,shape=[depth]))
    
    
    layer3_weights=tf.Variable(tf.truncated_normal
                               ([image_size//4*image_size//4*depth,num_hidden],stddev=0.1))
    layer3_biases=tf.Variable(tf.constant(1.0,shape=[num_hidden]))
    
    
    layer4_weights=tf.Variable(tf.truncated_normal
                               ([num_hidden,num_labels],stddev=0.1))
    layer4_biases=tf.Variable(tf.constant(1.0,shape=[num_labels]))
    
    #Model
    def model(data):
        conv=tf.nn.conv2d(data,layer1_weights,[1,2,2,1], padding='SAME')
        hidden=tf.nn.relu(conv+layer1_biases)
        conv=tf.nn.conv2d(hidden,layer2_weights,[1,2,2,1], padding='SAME')
        hidden=tf.nn.relu(conv+layer2_biases)
        shape=hidden.get_shape().as_list()
        reshape=tf.reshape(hidden,[shape[0],shape[1]*shape[2]*shape[3]])
        hidden=tf.nn.relu(tf.matmul(reshape, layer3_weights)+layer3_biases)
        return tf.matmul(hidden, layer4_weights)+ layer4_biases
    
    #training computation
    
    logits=model(tf_train_dataset)
    loss=tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels,logits=logits))
    
    #optimizer
    
    optimizer=tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    
    #Predictions for the training , validation, and test data
    
    train_prediction= tf.nn.softmax(logits)
    valid_prediction= tf.nn.softmax(model(tf_valid_dataset))
    test_prediction= tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps=10001

with tf.Session(graph=graph)as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset=(step*batch_size)% (train_labels.shape[0]-batch_size)
        batch_data=train_dataset[offset:(offset+batch_size),:,:,:]
        batch_labels=train_labels[offset:(offset+batch_size),:]
        feed_dict={tf_train_dataset : batch_data,tf_train_labels: batch_labels}
        _, l, predictions =session.run([optimizer,loss,train_prediction],feed_dict=feed_dict)
        if(step%50==0):
            print('Minibatch loss a step %d: %f' %(step,l))
            print('Minibatch Accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%'%accuracy(valid_prediction.eval(),valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss a step 0: 3.263589
# Minibatch Accuracy: 12.5%
# Validation accuracy: 11.4%
# Minibatch loss a step 50: 1.235159
# Minibatch Accuracy: 56.2%
# Validation accuracy: 50.5%
# Minibatch loss a step 100: 1.398365
# Minibatch Accuracy: 62.5%
# Validation accuracy: 72.7%
# Minibatch loss a step 150: 0.792629
# Minibatch Accuracy: 75.0%
# Validation accuracy: 76.2%
# Minibatch loss a step 200: 0.529968
# Minibatch Accuracy: 81.2%
# Validation accuracy: 79.1%
# Minibatch loss a step 250: 0.953043
# Minibatch Accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss a step 300: 0.644519
# Minibatch Accuracy: 75.0%
# Validation accuracy: 80.4%
# Minibatch loss a step 350: 0.293357
# Minibatch Accuracy: 87.5%
# Validation accuracy: 79.4%
# Minibatch loss a step 400: 0.484874
# Minibatch Accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss a step 450: 1.102701
# Minibatch Accuracy: 62.5%
# Validation accuracy: 80.3%
# Minibatch loss a step 500: 0.256470
# Minibatch Accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss a step 550: 0.698342
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss a step 600: 0.888393
# Minibatch Accuracy: 68.8%
# Validation accuracy: 79.7%
# Minibatch loss a step 650: 0.610606
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss a step 700: 0.559245
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss a step 750: 1.068907
# Minibatch Accuracy: 56.2%
# Validation accuracy: 82.5%
# Minibatch loss a step 800: 0.692194
# Minibatch Accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss a step 850: 0.558047
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss a step 900: 0.621037
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss a step 950: 0.477017
# Minibatch Accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss a step 1000: 0.280810
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss a step 1050: 0.361571
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss a step 1100: 0.436505
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss a step 1150: 0.532202
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss a step 1200: 0.417689
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss a step 1250: 0.816203
# Minibatch Accuracy: 75.0%
# Validation accuracy: 83.3%
# Minibatch loss a step 1300: 0.319628
# Minibatch Accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss a step 1350: 0.486105
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss a step 1400: 0.344546
# Minibatch Accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss a step 1450: 0.635436
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss a step 1500: 0.535002
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss a step 1550: 0.988752
# Minibatch Accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss a step 1600: 0.459426
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss a step 1650: 0.826918
# Minibatch Accuracy: 75.0%
# Validation accuracy: 84.6%
# Minibatch loss a step 1700: 0.621512
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss a step 1750: 0.126572
# Minibatch Accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss a step 1800: 0.643095
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss a step 1850: 0.172751
# Minibatch Accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss a step 1900: 0.729301
# Minibatch Accuracy: 68.8%
# Validation accuracy: 84.9%
# Minibatch loss a step 1950: 0.394060
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss a step 2000: 0.732477
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss a step 2050: 1.160692
# Minibatch Accuracy: 68.8%
# Validation accuracy: 85.1%
# Minibatch loss a step 2100: 0.673030
# Minibatch Accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss a step 2150: 0.053498
# Minibatch Accuracy: 100.0%
# Validation accuracy: 84.9%
# Minibatch loss a step 2200: 0.858812
# Minibatch Accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss a step 2250: 0.780794
# Minibatch Accuracy: 75.0%
# Validation accuracy: 85.5%
# Minibatch loss a step 2300: 0.569108
# Minibatch Accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss a step 2350: 0.201218
# Minibatch Accuracy: 100.0%
# Validation accuracy: 85.3%
# Minibatch loss a step 2400: 0.412050
# Minibatch Accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss a step 2450: 0.317384
# Minibatch Accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss a step 2500: 0.233115
# Minibatch Accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss a step 2550: 0.464390
# Minibatch Accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss a step 2600: 0.679264
# Minibatch Accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss a step 2650: 0.299235
# Minibatch Accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss a step 2700: 0.306253
# Minibatch Accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss a step 2750: 0.346532
# Minibatch Accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss a step 2800: 0.686981
# Minibatch Accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss a step 2850: 0.511791
# Minibatch Accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss a step 2900: 0.703921
# Minibatch Accuracy: 68.8%
# Validation accuracy: 85.8%
# Minibatch loss a step 2950: 0.060502
# Minibatch Accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss a step 3000: 0.387622
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss a step 3050: 0.795263
# Minibatch Accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss a step 3100: 0.294077
# Minibatch Accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss a step 3150: 0.325241
# Minibatch Accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss a step 3200: 0.596439
# Minibatch Accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss a step 3250: 0.331737
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss a step 3300: 0.407817
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss a step 3350: 0.246927
# Minibatch Accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss a step 3400: 0.243079
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss a step 3450: 0.210868
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss a step 3500: 0.265466
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss a step 3550: 0.704636
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss a step 3600: 0.342449
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss a step 3650: 0.198904
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss a step 3700: 0.102571
# Minibatch Accuracy: 100.0%
# Validation accuracy: 86.7%
# Minibatch loss a step 3750: 0.693498
# Minibatch Accuracy: 75.0%
# Validation accuracy: 86.9%
# Minibatch loss a step 3800: 0.564823
# Minibatch Accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss a step 3850: 0.478220
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss a step 3900: 0.584362
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss a step 3950: 0.349878
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss a step 4000: 0.911153
# Minibatch Accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss a step 4050: 0.638184
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss a step 4100: 0.371978
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss a step 4150: 0.156682
# Minibatch Accuracy: 100.0%
# Validation accuracy: 86.2%
# Minibatch loss a step 4200: 0.249393
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss a step 4250: 0.550579
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss a step 4300: 0.137351
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss a step 4350: 0.796448
# Minibatch Accuracy: 68.8%
# Validation accuracy: 86.6%
# Minibatch loss a step 4400: 0.257832
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss a step 4450: 0.502439
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss a step 4500: 0.241502
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss a step 4550: 0.270918
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss a step 4600: 0.768336
# Minibatch Accuracy: 68.8%
# Validation accuracy: 86.8%
# Minibatch loss a step 4650: 0.228446
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss a step 4700: 0.351525
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss a step 4750: 0.069801
# Minibatch Accuracy: 100.0%
# Validation accuracy: 86.8%
# Minibatch loss a step 4800: 0.726846
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss a step 4850: 0.778819
# Minibatch Accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss a step 4900: 0.207645
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss a step 4950: 0.347578
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss a step 5000: 0.321906
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss a step 5050: 0.558238
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss a step 5100: 0.012477
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.5%
# Minibatch loss a step 5150: 0.464405
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss a step 5200: 0.295791
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss a step 5250: 0.355901
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss a step 5300: 0.204732
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss a step 5350: 0.235345
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss a step 5400: 0.623043
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss a step 5450: 0.455202
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss a step 5500: 0.452826
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss a step 5550: 0.131470
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss a step 5600: 0.448132
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss a step 5650: 0.059734
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.4%
# Minibatch loss a step 5700: 0.563097
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss a step 5750: 0.797593
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.2%
# Minibatch loss a step 5800: 0.458860
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss a step 5850: 0.335615
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss a step 5900: 0.576483
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss a step 5950: 0.581325
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss a step 6000: 0.343326
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss a step 6050: 0.978285
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss a step 6100: 0.121464
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss a step 6150: 0.207661
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss a step 6200: 0.321726
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss a step 6250: 0.487013
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss a step 6300: 0.372739
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss a step 6350: 0.578795
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss a step 6400: 0.456414
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss a step 6450: 0.035670
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss a step 6500: 0.266626
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss a step 6550: 0.280199
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss a step 6600: 0.504623
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss a step 6650: 0.702269
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss a step 6700: 0.914585
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss a step 6750: 0.534590
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.8%
# Minibatch loss a step 6800: 0.436088
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss a step 6850: 0.639253
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss a step 6900: 1.129836
# Minibatch Accuracy: 68.8%
# Validation accuracy: 87.8%
# Minibatch loss a step 6950: 0.569101
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss a step 7000: 0.323447
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss a step 7050: 0.466742
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss a step 7100: 0.853863
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.4%
# Minibatch loss a step 7150: 0.358570
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss a step 7200: 0.458933
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss a step 7250: 0.617326
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss a step 7300: 0.332754
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss a step 7350: 0.542713
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss a step 7400: 0.322509
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss a step 7450: 0.334012
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss a step 7500: 0.217024
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss a step 7550: 0.175941
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.6%
# Minibatch loss a step 7600: 0.230259
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss a step 7650: 0.270661
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss a step 7700: 0.597163
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.8%
# Minibatch loss a step 7750: 0.329807
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss a step 7800: 0.220932
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss a step 7850: 0.263953
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss a step 7900: 1.107652
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss a step 7950: 0.259481
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss a step 8000: 0.548522
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss a step 8050: 0.070653
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss a step 8100: 0.629910
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss a step 8150: 0.643902
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss a step 8200: 0.122748
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss a step 8250: 0.635382
# Minibatch Accuracy: 68.8%
# Validation accuracy: 88.3%
# Minibatch loss a step 8300: 0.382307
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss a step 8350: 0.892333
# Minibatch Accuracy: 68.8%
# Validation accuracy: 88.1%
# Minibatch loss a step 8400: 0.404157
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss a step 8450: 0.754224
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss a step 8500: 0.018144
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss a step 8550: 0.122176
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss a step 8600: 0.398339
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss a step 8650: 0.382874
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss a step 8700: 0.584781
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss a step 8750: 0.362376
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss a step 8800: 0.711387
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.1%
# Minibatch loss a step 8850: 0.072954
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss a step 8900: 0.006860
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss a step 8950: 0.152426
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss a step 9000: 0.167734
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss a step 9050: 0.669688
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss a step 9100: 0.040384
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss a step 9150: 0.338222
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss a step 9200: 0.313886
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss a step 9250: 0.627855
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss a step 9300: 0.389370
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss a step 9350: 0.449124
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss a step 9400: 0.160518
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss a step 9450: 0.780779
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss a step 9500: 0.611085
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss a step 9550: 0.035243
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss a step 9600: 0.152531
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss a step 9650: 0.454504
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss a step 9700: 0.450357
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss a step 9750: 0.622431
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss a step 9800: 0.286849
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss a step 9850: 0.763603
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss a step 9900: 0.106276
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss a step 9950: 0.040028
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss a step 10000: 0.066912
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.2%
# Test accuracy: 94.1%

# %% [markdown]
# # convulation using maxpooling operation(nn.max_pool()) of stride of 2 and kernel size 2.

# %%
batch_size=16
patch_size=5
depth=16
num_hidden=64

graph=tf.Graph()

with graph.as_default():
    
    #input data
    tf_train_dataset=tf.placeholder(tf.float32, 
                                    shape=(batch_size,image_size,image_size,num_channels))
    tf_train_labels=tf.placeholder(tf.float32, shape=(batch_size,num_labels))
    tf_valid_dataset=tf.constant(valid_dataset)
    tf_test_dataset=tf.constant(test_dataset)
    
    #variables
    layer1_weights=tf.Variable(tf.truncated_normal
                               ([patch_size,patch_size,num_channels,depth],stddev=0.1))
    layer1_biases=tf.Variable(tf.zeros([depth]))
    
    layer2_weights=tf.Variable(tf.truncated_normal
                               ([patch_size,patch_size,depth,depth],stddev=0.1))
    layer2_biases=tf.Variable(tf.constant(1.0,shape=[depth]))
    
    
    layer3_weights=tf.Variable(tf.truncated_normal
                               ([image_size//4*image_size//4*depth,num_hidden],stddev=0.1))
    layer3_biases=tf.Variable(tf.constant(1.0,shape=[num_hidden]))
    
    
    layer4_weights=tf.Variable(tf.truncated_normal
                               ([num_hidden,num_labels],stddev=0.1))
    layer4_biases=tf.Variable(tf.constant(1.0,shape=[num_labels]))
    
    #Model
    def model(data):
        #1st conv layer with pooling
        conv_1=tf.nn.conv2d(data,layer1_weights,[1,1,1,1], padding='SAME')
        hidden_1=tf.nn.relu(conv_1+layer1_biases)
        pool_1=tf.nn.max_pool(hidden_1,[1,2,2,1],[1,2,2,1], padding='SAME')
        
         #2nd conv layer with pooling
        conv_2=tf.nn.conv2d(pool_1,layer2_weights,[1,1,1,1], padding='SAME')
        hidden_2=tf.nn.relu(conv_2+layer2_biases)
        pool_2=tf.nn.max_pool(hidden_2,[1,2,2,1],[1,2,2,1], padding='SAME')
        
         #fully connected layer
        shape=pool_2.get_shape().as_list()
        reshape=tf.reshape(pool_2,[shape[0],shape[1]*shape[2]*shape[3]])
        hidden=tf.nn.relu(tf.matmul(reshape, layer3_weights)+layer3_biases)
        return tf.matmul(hidden, layer4_weights)+ layer4_biases
    
    #training computation
    
    logits=model(tf_train_dataset)
    loss=tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels,logits=logits))
    
    #optimizer
    
    optimizer=tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    
    #Predictions for the training , validation, and test data
    
    train_prediction= tf.nn.softmax(logits)
    valid_prediction= tf.nn.softmax(model(tf_valid_dataset))
    test_prediction= tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps=10001

with tf.Session(graph=graph)as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset=(step*batch_size)% (train_labels.shape[0]-batch_size)
        batch_data=train_dataset[offset:(offset+batch_size),:,:,:]
        batch_labels=train_labels[offset:(offset+batch_size),:]
        feed_dict={tf_train_dataset : batch_data,tf_train_labels: batch_labels}
        _, l, predictions =session.run([optimizer,loss,train_prediction],feed_dict=feed_dict)
        if(step%50==0):
            print('Minibatch loss a step %d: %f' %(step,l))
            print('Minibatch Accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%'%accuracy(valid_prediction.eval(),valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss a step 0: 3.003009
# Minibatch Accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss a step 50: 2.212623
# Minibatch Accuracy: 18.8%
# Validation accuracy: 22.5%
# Minibatch loss a step 100: 1.873110
# Minibatch Accuracy: 56.2%
# Validation accuracy: 64.0%
# Minibatch loss a step 150: 1.151364
# Minibatch Accuracy: 62.5%
# Validation accuracy: 74.0%
# Minibatch loss a step 200: 0.864053
# Minibatch Accuracy: 75.0%
# Validation accuracy: 76.9%
# Minibatch loss a step 250: 0.878512
# Minibatch Accuracy: 81.2%
# Validation accuracy: 80.1%
# Minibatch loss a step 300: 0.861306
# Minibatch Accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss a step 350: 0.286721
# Minibatch Accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss a step 400: 0.684663
# Minibatch Accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss a step 450: 1.018541
# Minibatch Accuracy: 68.8%
# Validation accuracy: 80.2%
# Minibatch loss a step 500: 0.296469
# Minibatch Accuracy: 93.8%
# Validation accuracy: 81.6%
# Minibatch loss a step 550: 0.641579
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss a step 600: 0.649679
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss a step 650: 0.781651
# Minibatch Accuracy: 68.8%
# Validation accuracy: 82.4%
# Minibatch loss a step 700: 0.450979
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss a step 750: 1.052706
# Minibatch Accuracy: 56.2%
# Validation accuracy: 83.7%
# Minibatch loss a step 800: 0.688352
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss a step 850: 0.592277
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss a step 900: 0.885100
# Minibatch Accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss a step 950: 0.466930
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss a step 1000: 0.247674
# Minibatch Accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss a step 1050: 0.270038
# Minibatch Accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss a step 1100: 0.322728
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss a step 1150: 0.448804
# Minibatch Accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss a step 1200: 0.400132
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss a step 1250: 0.407326
# Minibatch Accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss a step 1300: 0.339660
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss a step 1350: 0.384069
# Minibatch Accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss a step 1400: 0.482854
# Minibatch Accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss a step 1450: 0.502703
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss a step 1500: 0.329028
# Minibatch Accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss a step 1550: 0.839681
# Minibatch Accuracy: 68.8%
# Validation accuracy: 84.6%
# Minibatch loss a step 1600: 0.271553
# Minibatch Accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss a step 1650: 0.841444
# Minibatch Accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss a step 1700: 0.791353
# Minibatch Accuracy: 68.8%
# Validation accuracy: 84.2%
# Minibatch loss a step 1750: 0.056849
# Minibatch Accuracy: 100.0%
# Validation accuracy: 84.6%
# Minibatch loss a step 1800: 0.625778
# Minibatch Accuracy: 68.8%
# Validation accuracy: 85.0%
# Minibatch loss a step 1850: 0.040640
# Minibatch Accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss a step 1900: 0.905807
# Minibatch Accuracy: 68.8%
# Validation accuracy: 85.0%
# Minibatch loss a step 1950: 0.342043
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss a step 2000: 0.982745
# Minibatch Accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss a step 2050: 0.850094
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss a step 2100: 0.386307
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss a step 2150: 0.021638
# Minibatch Accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss a step 2200: 0.771716
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss a step 2250: 0.842482
# Minibatch Accuracy: 75.0%
# Validation accuracy: 86.3%
# Minibatch loss a step 2300: 0.719025
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss a step 2350: 0.152305
# Minibatch Accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss a step 2400: 0.504649
# Minibatch Accuracy: 75.0%
# Validation accuracy: 86.6%
# Minibatch loss a step 2450: 0.331371
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss a step 2500: 0.333301
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss a step 2550: 0.339062
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss a step 2600: 0.725228
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss a step 2650: 0.211158
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss a step 2700: 0.316759
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss a step 2750: 0.380918
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss a step 2800: 0.684317
# Minibatch Accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss a step 2850: 0.474821
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss a step 2900: 0.798109
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss a step 2950: 0.061450
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.1%
# Minibatch loss a step 3000: 0.450254
# Minibatch Accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss a step 3050: 0.668155
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss a step 3100: 0.196934
# Minibatch Accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss a step 3150: 0.349893
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss a step 3200: 0.419402
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss a step 3250: 0.216585
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss a step 3300: 0.510315
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss a step 3350: 0.170956
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss a step 3400: 0.193297
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss a step 3450: 0.179509
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss a step 3500: 0.424015
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss a step 3550: 0.740680
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss a step 3600: 0.386130
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss a step 3650: 0.350773
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss a step 3700: 0.166730
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss a step 3750: 0.630190
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss a step 3800: 0.564314
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss a step 3850: 0.443560
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss a step 3900: 0.354403
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss a step 3950: 0.432873
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss a step 4000: 0.851336
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.1%
# Minibatch loss a step 4050: 0.789729
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss a step 4100: 0.515935
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss a step 4150: 0.210180
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss a step 4200: 0.252431
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss a step 4250: 0.388201
# Minibatch Accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss a step 4300: 0.201336
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss a step 4350: 0.646825
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.1%
# Minibatch loss a step 4400: 0.404517
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss a step 4450: 0.594803
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss a step 4500: 0.136694
# Minibatch Accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss a step 4550: 0.299809
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss a step 4600: 0.680829
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss a step 4650: 0.316954
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss a step 4700: 0.492077
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss a step 4750: 0.115291
# Minibatch Accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss a step 4800: 0.866716
# Minibatch Accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss a step 4850: 0.760916
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss a step 4900: 0.232131
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss a step 4950: 0.261000
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss a step 5000: 0.150619
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss a step 5050: 0.652745
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss a step 5100: 0.055051
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss a step 5150: 0.483077
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss a step 5200: 0.470431
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss a step 5250: 0.392656
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss a step 5300: 0.236383
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss a step 5350: 0.118554
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss a step 5400: 0.561852
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss a step 5450: 0.463083
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss a step 5500: 0.398436
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss a step 5550: 0.215859
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss a step 5600: 0.471473
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss a step 5650: 0.065227
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss a step 5700: 0.481338
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss a step 5750: 1.257472
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss a step 5800: 0.539979
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss a step 5850: 0.196809
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss a step 5900: 0.672569
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.4%
# Minibatch loss a step 5950: 0.461768
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss a step 6000: 0.301309
# Minibatch Accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss a step 6050: 0.871265
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss a step 6100: 0.160511
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss a step 6150: 0.121970
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss a step 6200: 0.316890
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss a step 6250: 0.429035
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss a step 6300: 0.397547
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss a step 6350: 0.465448
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss a step 6400: 0.346501
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss a step 6450: 0.081637
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss a step 6500: 0.185298
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss a step 6550: 0.330198
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss a step 6600: 0.571836
# Minibatch Accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss a step 6650: 0.595937
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss a step 6700: 0.814040
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss a step 6750: 0.411030
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss a step 6800: 0.429160
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss a step 6850: 0.630666
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss a step 6900: 1.023913
# Minibatch Accuracy: 68.8%
# Validation accuracy: 88.2%
# Minibatch loss a step 6950: 0.805691
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.5%
# Minibatch loss a step 7000: 0.406107
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss a step 7050: 0.271723
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss a step 7100: 0.704097
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss a step 7150: 0.279100
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss a step 7200: 0.471293
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss a step 7250: 0.764270
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss a step 7300: 0.437891
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss a step 7350: 0.531363
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss a step 7400: 0.159981
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss a step 7450: 0.369235
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss a step 7500: 0.209557
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss a step 7550: 0.105002
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss a step 7600: 0.336519
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss a step 7650: 0.390906
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss a step 7700: 0.542022
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss a step 7750: 0.385262
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss a step 7800: 0.190926
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss a step 7850: 0.295190
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss a step 7900: 0.963099
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss a step 7950: 0.218528
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss a step 8000: 0.475013
# Minibatch Accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss a step 8050: 0.031044
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss a step 8100: 0.713894
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss a step 8150: 0.728638
# Minibatch Accuracy: 68.8%
# Validation accuracy: 88.8%
# Minibatch loss a step 8200: 0.101293
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss a step 8250: 0.537755
# Minibatch Accuracy: 75.0%
# Validation accuracy: 88.7%
# Minibatch loss a step 8300: 0.298310
# Minibatch Accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss a step 8350: 0.581763
# Minibatch Accuracy: 75.0%
# Validation accuracy: 89.0%
# Minibatch loss a step 8400: 0.489128
# Minibatch Accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss a step 8450: 0.784184
# Minibatch Accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss a step 8500: 0.110386
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss a step 8550: 0.304949
# Minibatch Accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss a step 8600: 0.420967
# Minibatch Accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss a step 8650: 0.270456
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss a step 8700: 0.267968
# Minibatch Accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss a step 8750: 0.380390
# Minibatch Accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss a step 8800: 0.562327
# Minibatch Accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss a step 8850: 0.087717
# Minibatch Accuracy: 100.0%
# Validation accuracy: 89.3%
# Minibatch loss a step 8900: 0.013431
# Minibatch Accuracy: 100.0%
# Validation accuracy: 89.1%
# Minibatch loss a step 8950: 0.156052
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss a step 9000: 0.228479
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss a step 9050: 0.685932
# Minibatch Accuracy: 75.0%
# Validation accuracy: 89.2%
# Minibatch loss a step 9100: 0.060179
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss a step 9150: 0.285763
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss a step 9200: 0.180853
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss a step 9250: 0.666255
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss a step 9300: 0.445903
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss a step 9350: 0.570814
# Minibatch Accuracy: 75.0%
# Validation accuracy: 89.2%
# Minibatch loss a step 9400: 0.054248
# Minibatch Accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss a step 9450: 0.635755
# Minibatch Accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss a step 9500: 0.383941
# Minibatch Accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss a step 9550: 0.068292
# Minibatch Accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss a step 9600: 0.187101
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss a step 9650: 0.412991
# Minibatch Accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss a step 9700: 0.245654
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss a step 9750: 0.638207
# Minibatch Accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss a step 9800: 0.396564
# Minibatch Accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss a step 9850: 0.601796
# Minibatch Accuracy: 75.0%
# Validation accuracy: 89.2%
# Minibatch loss a step 9900: 0.084476
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss a step 9950: 0.154194
# Minibatch Accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss a step 10000: 0.229965
# Minibatch Accuracy: 93.8%
# Validation accuracy: 88.6%
# Test accuracy: 94.6%

# %% [markdown]
# # conv with dropout

# %%
image_size=28
#create image size function based on input, filter size, padding and stride
#2 convolutions only with 2 pooling
def output_size_pool(input_size, conv_filter_size,pool_filter_size, padding, conv_stride, pool_stride):
    if padding =='same':
        padding=-1.00
    elif padding=='valid':
        padding=0.00
    else:
        return None
    #after convolution 1
    output_1=(((input_size-conv_filter_size-2*padding)/ conv_stride)+1.00)
    #after pool 1
    output_2=(((output_1-pool_filter_size-2*padding)/pool_stride)+1.00)
    #After convolution 2
    output_3=(((output_2-conv_filter_size-2*padding)/conv_stride)+1.00)
    #after pool 2
    output_4=(((output_3-pool_filter_size-2*padding)/pool_stride)+1.00)
    return int(output_4)
final_image_size=output_size_pool(
    input_size=image_size,conv_filter_size=5,pool_filter_size=2,
    padding='valid', conv_stride=1, pool_stride=2)
print(final_image_size)
# Out:
# 4

# %%
batch_size=16
patch_size=5
depth=32
num_hidden=64
beta=0.001

graph=tf.Graph()

with graph.as_default():
    
    #input data
    tf_train_dataset=tf.placeholder(tf.float32, 
                                    shape=(batch_size,image_size,image_size,num_channels))
    tf_train_labels=tf.placeholder(tf.float32, shape=(batch_size,num_labels))
    tf_valid_dataset=tf.constant(valid_dataset)
    tf_test_dataset=tf.constant(test_dataset)
    
    #variables
    layer1_weights=tf.Variable(tf.truncated_normal
                               ([patch_size,patch_size,num_channels,depth],stddev=0.1))
    layer1_biases=tf.Variable(tf.zeros([depth]))
    
    layer2_weights=tf.Variable(tf.truncated_normal
                               ([patch_size,patch_size,depth,depth],stddev=0.1))
    layer2_biases=tf.Variable(tf.constant(1.0,shape=[depth]))
    
    final_image_size=output_size_pool(input_size=image_size,
                                      conv_filter_size=5,pool_filter_size=2,padding='valid',
                                      conv_stride=1,pool_stride=2)
    
    
    layer3_weights=tf.Variable(tf.truncated_normal
                               ([final_image_size*final_image_size*depth,num_hidden],stddev=0.1))
    layer3_biases=tf.Variable(tf.constant(1.0,shape=[num_hidden]))
    
    
    layer4_weights=tf.Variable(tf.truncated_normal
                               ([num_hidden,num_hidden],stddev=0.1))
    layer4_biases=tf.Variable(tf.constant(1.0,shape=[num_hidden]))
    
    
    
    layer5_weights=tf.Variable(tf.truncated_normal
                               ([num_hidden,num_labels],stddev=0.1))
    layer5_biases=tf.Variable(tf.constant(1.0,shape=[num_labels]))
    
    #Model
    def model(data):
        #1st conv layer with pooling
        conv_1=tf.nn.conv2d(data,layer1_weights,[1,1,1,1], padding='VALID')
        hidden_1=tf.nn.relu(conv_1+layer1_biases)
        pool_1=tf.nn.avg_pool(hidden_1,[1,2,2,1],[1,2,2,1], padding='VALID')
        
         #2nd conv layer with pooling
        conv_2=tf.nn.conv2d(pool_1,layer2_weights,[1,1,1,1], padding='VALID')
        hidden_2=tf.nn.relu(conv_2+layer2_biases)
        pool_2=tf.nn.avg_pool(hidden_2,[1,2,2,1],[1,2,2,1], padding='VALID')
        
         #1st fully connected layer
        shape=pool_2.get_shape().as_list()
        reshape=tf.reshape(pool_2,[shape[0],shape[1]*shape[2]*shape[3]])
        hidden=tf.nn.relu(tf.matmul(reshape, layer3_weights)+layer3_biases)
        keep_prob=0.5
        hidden_drop=tf.nn.dropout(hidden,keep_prob)
        
        #2nd fully connected layer
        hidden_2=tf.nn.relu(tf.matmul(hidden_drop, layer4_weights)+layer4_biases)
        hidden_2_drop=tf.nn.dropout(hidden_2,keep_prob)
        
        return tf.matmul(hidden_2_drop, layer5_weights)+ layer5_biases
    
    #training computation
    
    logits=model(tf_train_dataset)
    loss=tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels,logits=logits))
    
    #optimizer
    global_step=tf.Variable(0)
    start_learning_rate=0.05
    learning_rate=tf.train.exponential_decay(start_learning_rate, global_step,100000,0.96,
                                             staircase=True)
    
    optimizer=tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
    
    #Predictions for the training , validation, and test data
    
    train_prediction= tf.nn.softmax(logits)
    valid_prediction= tf.nn.softmax(model(tf_valid_dataset))
    test_prediction= tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps=20000

with tf.Session(graph=graph)as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset=(step*batch_size)% (train_labels.shape[0]-batch_size)
        batch_data=train_dataset[offset:(offset+batch_size),:,:,:]
        batch_labels=train_labels[offset:(offset+batch_size),:]
        feed_dict={tf_train_dataset : batch_data,tf_train_labels: batch_labels}
        _, l, predictions =session.run([optimizer,loss,train_prediction],feed_dict=feed_dict)
        if(step%50==0):
            print('Minibatch loss a step %d: %f' %(step,l))
            print('Minibatch Accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%'%accuracy(valid_prediction.eval(),valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss a step 0: 3.780119
# Minibatch Accuracy: 6.2%
# Validation accuracy: 9.8%
# Minibatch loss a step 50: 2.171072
# Minibatch Accuracy: 31.2%
# Validation accuracy: 18.9%
# Minibatch loss a step 100: 2.094043
# Minibatch Accuracy: 18.8%
# Validation accuracy: 26.3%
# Minibatch loss a step 150: 1.615469
# Minibatch Accuracy: 43.8%
# Validation accuracy: 34.4%
# Minibatch loss a step 200: 1.728094
# Minibatch Accuracy: 37.5%
# Validation accuracy: 38.7%
# Minibatch loss a step 250: 1.742614
# Minibatch Accuracy: 31.2%
# Validation accuracy: 43.0%
# Minibatch loss a step 300: 1.413950
# Minibatch Accuracy: 56.2%
# Validation accuracy: 46.7%
# Minibatch loss a step 350: 1.089064
# Minibatch Accuracy: 62.5%
# Validation accuracy: 48.1%
# Minibatch loss a step 400: 1.185003
# Minibatch Accuracy: 68.8%
# Validation accuracy: 50.5%
# Minibatch loss a step 450: 1.873650
# Minibatch Accuracy: 37.5%
# Validation accuracy: 49.9%
# Minibatch loss a step 500: 1.279022
# Minibatch Accuracy: 68.8%
# Validation accuracy: 54.8%
# Minibatch loss a step 550: 1.252220
# Minibatch Accuracy: 50.0%
# Validation accuracy: 56.0%
# Minibatch loss a step 600: 1.303950
# Minibatch Accuracy: 50.0%
# Validation accuracy: 56.8%
# Minibatch loss a step 650: 1.022941
# Minibatch Accuracy: 68.8%
# Validation accuracy: 59.5%
# Minibatch loss a step 700: 1.126911
# Minibatch Accuracy: 62.5%
# Validation accuracy: 60.4%
# Minibatch loss a step 750: 1.334337
# Minibatch Accuracy: 56.2%
# Validation accuracy: 58.2%
# Minibatch loss a step 800: 1.271710
# Minibatch Accuracy: 56.2%
# Validation accuracy: 63.0%
# Minibatch loss a step 850: 0.773936
# Minibatch Accuracy: 68.8%
# Validation accuracy: 62.5%
# Minibatch loss a step 900: 0.978261
# Minibatch Accuracy: 68.8%
# Validation accuracy: 62.3%
# Minibatch loss a step 950: 0.706669
# Minibatch Accuracy: 81.2%
# Validation accuracy: 67.2%
# Minibatch loss a step 1000: 0.494221
# Minibatch Accuracy: 81.2%
# Validation accuracy: 64.8%
# Minibatch loss a step 1050: 0.969645
# Minibatch Accuracy: 68.8%
# Validation accuracy: 67.1%
# Minibatch loss a step 1100: 0.551510
# Minibatch Accuracy: 87.5%
# Validation accuracy: 65.4%
# Minibatch loss a step 1150: 1.011736
# Minibatch Accuracy: 62.5%
# Validation accuracy: 66.8%
# Minibatch loss a step 1200: 1.115346
# Minibatch Accuracy: 62.5%
# Validation accuracy: 68.8%
# Minibatch loss a step 1250: 2.035048
# Minibatch Accuracy: 37.5%
# Validation accuracy: 69.5%
# Minibatch loss a step 1300: 0.757519
# Minibatch Accuracy: 75.0%
# Validation accuracy: 70.2%
# Minibatch loss a step 1350: 0.836275
# Minibatch Accuracy: 81.2%
# Validation accuracy: 71.2%
# Minibatch loss a step 1400: 1.173862
# Minibatch Accuracy: 56.2%
# Validation accuracy: 67.8%
# Minibatch loss a step 1450: 0.736089
# Minibatch Accuracy: 68.8%
# Validation accuracy: 71.6%
# Minibatch loss a step 1500: 0.903658
# Minibatch Accuracy: 68.8%
# Validation accuracy: 72.2%
# Minibatch loss a step 1550: 1.362721
# Minibatch Accuracy: 75.0%
# Validation accuracy: 72.6%
# Minibatch loss a step 1600: 1.034098
# Minibatch Accuracy: 75.0%
# Validation accuracy: 71.9%
# Minibatch loss a step 1650: 1.071292
# Minibatch Accuracy: 75.0%
# Validation accuracy: 72.1%
# Minibatch loss a step 1700: 1.144888
# Minibatch Accuracy: 62.5%
# Validation accuracy: 72.6%
# Minibatch loss a step 1750: 0.648340
# Minibatch Accuracy: 81.2%
# Validation accuracy: 71.9%
# Minibatch loss a step 1800: 0.874272
# Minibatch Accuracy: 75.0%
# Validation accuracy: 73.7%
# Minibatch loss a step 1850: 0.447795
# Minibatch Accuracy: 87.5%
# Validation accuracy: 74.0%
# Minibatch loss a step 1900: 1.254242
# Minibatch Accuracy: 56.2%
# Validation accuracy: 73.9%
# Minibatch loss a step 1950: 0.638629
# Minibatch Accuracy: 68.8%
# Validation accuracy: 75.1%
# Minibatch loss a step 2000: 0.850596
# Minibatch Accuracy: 87.5%
# Validation accuracy: 74.4%
# Minibatch loss a step 2050: 1.783537
# Minibatch Accuracy: 62.5%
# Validation accuracy: 75.7%
# Minibatch loss a step 2100: 1.021379
# Minibatch Accuracy: 62.5%
# Validation accuracy: 76.3%
# Minibatch loss a step 2150: 0.422165
# Minibatch Accuracy: 100.0%
# Validation accuracy: 75.5%
# Minibatch loss a step 2200: 1.108720
# Minibatch Accuracy: 68.8%
# Validation accuracy: 74.3%
# Minibatch loss a step 2250: 0.711283
# Minibatch Accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss a step 2300: 1.079438
# Minibatch Accuracy: 68.8%
# Validation accuracy: 74.0%
# Minibatch loss a step 2350: 0.867514
# Minibatch Accuracy: 75.0%
# Validation accuracy: 75.1%
# Minibatch loss a step 2400: 0.559020
# Minibatch Accuracy: 81.2%
# Validation accuracy: 76.4%
# Minibatch loss a step 2450: 0.598849
# Minibatch Accuracy: 81.2%
# Validation accuracy: 76.1%
# Minibatch loss a step 2500: 0.414960
# Minibatch Accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss a step 2550: 0.752922
# Minibatch Accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss a step 2600: 1.358137
# Minibatch Accuracy: 56.2%
# Validation accuracy: 76.3%
# Minibatch loss a step 2650: 0.794512
# Minibatch Accuracy: 81.2%
# Validation accuracy: 77.4%
# Minibatch loss a step 2700: 0.655084
# Minibatch Accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss a step 2750: 0.517962
# Minibatch Accuracy: 81.2%
# Validation accuracy: 77.1%
# Minibatch loss a step 2800: 1.129318
# Minibatch Accuracy: 68.8%
# Validation accuracy: 76.9%
# Minibatch loss a step 2850: 0.610553
# Minibatch Accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss a step 2900: 1.206630
# Minibatch Accuracy: 68.8%
# Validation accuracy: 77.9%
# Minibatch loss a step 2950: 0.442163
# Minibatch Accuracy: 81.2%
# Validation accuracy: 77.6%
# Minibatch loss a step 3000: 0.569280
# Minibatch Accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss a step 3050: 1.259689
# Minibatch Accuracy: 56.2%
# Validation accuracy: 78.5%
# Minibatch loss a step 3100: 0.461590
# Minibatch Accuracy: 100.0%
# Validation accuracy: 78.3%
# Minibatch loss a step 3150: 0.571018
# Minibatch Accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss a step 3200: 0.869203
# Minibatch Accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss a step 3250: 0.561845
# Minibatch Accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss a step 3300: 0.626655
# Minibatch Accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss a step 3350: 0.690805
# Minibatch Accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss a step 3400: 0.313888
# Minibatch Accuracy: 93.8%
# Validation accuracy: 78.8%
# Minibatch loss a step 3450: 0.436179
# Minibatch Accuracy: 93.8%
# Validation accuracy: 78.8%
# Minibatch loss a step 3500: 0.523947
# Minibatch Accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss a step 3550: 0.710294
# Minibatch Accuracy: 81.2%
# Validation accuracy: 79.1%
# Minibatch loss a step 3600: 0.500288
# Minibatch Accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss a step 3650: 0.790108
# Minibatch Accuracy: 68.8%
# Validation accuracy: 79.8%
# Minibatch loss a step 3700: 0.695028
# Minibatch Accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss a step 3750: 1.097724
# Minibatch Accuracy: 68.8%
# Validation accuracy: 79.9%
# Minibatch loss a step 3800: 1.008247
# Minibatch Accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss a step 3850: 1.386397
# Minibatch Accuracy: 56.2%
# Validation accuracy: 79.2%
# Minibatch loss a step 3900: 0.808647
# Minibatch Accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss a step 3950: 0.624779
# Minibatch Accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss a step 4000: 1.259526
# Minibatch Accuracy: 68.8%
# Validation accuracy: 80.1%
# Minibatch loss a step 4050: 0.718463
# Minibatch Accuracy: 75.0%
# Validation accuracy: 79.4%
# Minibatch loss a step 4100: 0.824877
# Minibatch Accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss a step 4150: 0.521166
# Minibatch Accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss a step 4200: 0.422359
# Minibatch Accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss a step 4250: 0.442501
# Minibatch Accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss a step 4300: 0.091459
# Minibatch Accuracy: 100.0%
# Validation accuracy: 80.6%
# Minibatch loss a step 4350: 1.179265
# Minibatch Accuracy: 62.5%
# Validation accuracy: 79.6%
# Minibatch loss a step 4400: 0.600317
# Minibatch Accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss a step 4450: 1.260521
# Minibatch Accuracy: 62.5%
# Validation accuracy: 80.7%
# Minibatch loss a step 4500: 0.341886
# Minibatch Accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss a step 4550: 0.205240
# Minibatch Accuracy: 100.0%
# Validation accuracy: 81.2%
# Minibatch loss a step 4600: 1.286874
# Minibatch Accuracy: 62.5%
# Validation accuracy: 81.4%
# Minibatch loss a step 4650: 0.622548
# Minibatch Accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss a step 4700: 0.461466
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss a step 4750: 0.084462
# Minibatch Accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss a step 4800: 0.916935
# Minibatch Accuracy: 68.8%
# Validation accuracy: 79.1%
# Minibatch loss a step 4850: 1.108865
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.1%
# Minibatch loss a step 4900: 0.333151
# Minibatch Accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss a step 4950: 0.314810
# Minibatch Accuracy: 87.5%
# Validation accuracy: 80.7%
# Minibatch loss a step 5000: 0.311603
# Minibatch Accuracy: 93.8%
# Validation accuracy: 81.2%
# Minibatch loss a step 5050: 0.756057
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss a step 5100: 0.086312
# Minibatch Accuracy: 100.0%
# Validation accuracy: 81.4%
# Minibatch loss a step 5150: 0.648179
# Minibatch Accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss a step 5200: 0.722376
# Minibatch Accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss a step 5250: 0.485755
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss a step 5300: 0.721486
# Minibatch Accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss a step 5350: 0.351154
# Minibatch Accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss a step 5400: 1.475683
# Minibatch Accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss a step 5450: 1.031022
# Minibatch Accuracy: 68.8%
# Validation accuracy: 81.2%
# Minibatch loss a step 5500: 0.726036
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss a step 5550: 0.349644
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss a step 5600: 1.025789
# Minibatch Accuracy: 68.8%
# Validation accuracy: 81.5%
# Minibatch loss a step 5650: 0.344790
# Minibatch Accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss a step 5700: 0.548964
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss a step 5750: 1.446506
# Minibatch Accuracy: 68.8%
# Validation accuracy: 81.2%
# Minibatch loss a step 5800: 0.900822
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss a step 5850: 0.594105
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.6%
# Minibatch loss a step 5900: 0.686236
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss a step 5950: 0.431300
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss a step 6000: 0.505002
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss a step 6050: 0.985410
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss a step 6100: 0.592894
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss a step 6150: 0.355877
# Minibatch Accuracy: 93.8%
# Validation accuracy: 81.7%
# Minibatch loss a step 6200: 0.863228
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss a step 6250: 0.556569
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss a step 6300: 0.736330
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss a step 6350: 0.724689
# Minibatch Accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss a step 6400: 0.637166
# Minibatch Accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss a step 6450: 0.318425
# Minibatch Accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss a step 6500: 0.355804
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss a step 6550: 0.495885
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss a step 6600: 0.934173
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss a step 6650: 0.647678
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss a step 6700: 1.174487
# Minibatch Accuracy: 62.5%
# Validation accuracy: 82.3%
# Minibatch loss a step 6750: 0.775031
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss a step 6800: 0.395000
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss a step 6850: 0.845409
# Minibatch Accuracy: 62.5%
# Validation accuracy: 82.3%
# Minibatch loss a step 6900: 1.276957
# Minibatch Accuracy: 62.5%
# Validation accuracy: 82.5%
# Minibatch loss a step 6950: 0.671932
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss a step 7000: 0.780243
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss a step 7050: 1.041697
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss a step 7100: 1.181818
# Minibatch Accuracy: 68.8%
# Validation accuracy: 81.7%
# Minibatch loss a step 7150: 0.241005
# Minibatch Accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss a step 7200: 0.597159
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss a step 7250: 1.008057
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss a step 7300: 0.430859
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss a step 7350: 0.596165
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss a step 7400: 0.380967
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss a step 7450: 0.579593
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss a step 7500: 0.618004
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss a step 7550: 0.544023
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss a step 7600: 0.644810
# Minibatch Accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss a step 7650: 0.699376
# Minibatch Accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss a step 7700: 0.679760
# Minibatch Accuracy: 68.8%
# Validation accuracy: 83.4%
# Minibatch loss a step 7750: 0.527301
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss a step 7800: 0.480940
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss a step 7850: 0.773039
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss a step 7900: 1.438421
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss a step 7950: 0.321560
# Minibatch Accuracy: 93.8%
# Validation accuracy: 83.1%
# Minibatch loss a step 8000: 0.512144
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss a step 8050: 0.215034
# Minibatch Accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss a step 8100: 1.062242
# Minibatch Accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss a step 8150: 1.002949
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss a step 8200: 0.367173
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss a step 8250: 0.683761
# Minibatch Accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss a step 8300: 0.508740
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss a step 8350: 0.606877
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss a step 8400: 0.534731
# Minibatch Accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss a step 8450: 1.178397
# Minibatch Accuracy: 56.2%
# Validation accuracy: 83.1%
# Minibatch loss a step 8500: 0.171045
# Minibatch Accuracy: 100.0%
# Validation accuracy: 83.4%
# Minibatch loss a step 8550: 0.401154
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss a step 8600: 0.565942
# Minibatch Accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss a step 8650: 0.742235
# Minibatch Accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss a step 8700: 0.572469
# Minibatch Accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss a step 8750: 0.553925
# Minibatch Accuracy: 81.2%
# Validation accuracy: 82.5%
