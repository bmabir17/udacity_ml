# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile 
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file='notMNIST.pickle'


with open(pickle_file , 'rb') as f:
    save=pickle.load(f)
    train_dataset=save ['train_dataset']
    train_labels=save ['train_labels']
    valid_dataset=save ['valid_dataset']
    valid_labels=save ['valid_labels']
    test_dataset=save ['test_dataset']
    test_labels=save ['test_labels']
    del save #to help compiler to free up space 
    print('train_dataset', train_dataset.shape , train_labels.shape)
    print('validation set ', valid_dataset.shape, valid_labels.shape)
    print('test set', test_dataset.shape, test_labels.shape)
# Out:
# train_dataset (200000, 28, 28) (200000,)
# validation set  (10000, 28, 28) (10000,)
# test set (10000, 28, 28) (10000,)

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
    # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
log_dir='Hidden_1layer_log'
def accuracy(predictions, labels):
    return(100.0 * np.sum(np.argmax(predictions, 1)== np.argmax(labels, 1))/ predictions.shape[0])
def variable_summaries(var):
  """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
  with tf.name_scope('summaries'):
    mean = tf.reduce_mean(var)
    tf.summary.scalar('mean', mean)
    with tf.name_scope('stddev'):
        stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
    tf.summary.scalar('stddev', stddev)
    tf.summary.scalar('max', tf.reduce_max(var))
    tf.summary.scalar('min', tf.reduce_min(var))
    tf.summary.histogram('histogram', var)
if tf.gfile.Exists(log_dir):
    tf.gfile.DeleteRecursively(log_dir)
    tf.gfile.MakeDirs(log_dir)

# %%
batch_size=128 #for sgd mini batch
num_nodes=1024
#SGDSTEP=0.5
#NumberofLayers=2 #(front layer+1 hidden layer)

'''
def weight_variable(shape):
    initial=tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)
def bias_variable(shape):
    initial:tf.constant(0.1, shape=shape)
        return tf.Variable(initial)
        '''
sess = tf.InteractiveSession()    
graph=tf.Graph()
with graph.as_default():
    # Input data.For the training data,we use a placeholder to fed with a training mini batch
    #at runtime with a training min i batch
    tf_train_dataset= tf.placeholder(tf.float32, shape=(batch_size, image_size*image_size))
    
    tf_train_labels=tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset=tf.constant(valid_dataset)
    tf_test_dataset=tf.constant(test_dataset)
    
    with tf.name_scope('weights1'):
        weights_1=tf.Variable(tf.truncated_normal([image_size*image_size,num_nodes]))
        variable_summaries(weights_1)
    with tf.name_scope('biases1'):
        biases_1=tf.Variable(tf.zeros([num_nodes]))
        variable_summaries(biases_1)
    with tf.name_scope('weights2'):
        weights_2=tf.Variable(tf.truncated_normal([num_nodes, num_labels]))
        variable_summaries(weights_2)
    with tf.name_scope('biases2'):
        biases_2=tf.Variable(tf.zeros(num_labels))
        variable_summaries(biases_2)
    with tf.name_scope('W1x_plus_b1'):
        preactivate = tf.matmul(tf_train_dataset,weights_1)+ biases_1
        tf.summary.histogram('pre_activations1', preactivate)
    relu_layer=tf.nn.relu(preactivate)
    tf.summary.histogram('activations', relu_layer)
    
    #training Computation.
    
    logits=tf.matmul(relu_layer,weights_2)+biases_2
    #loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    #loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels,logits=logits))
    
    
    with tf.name_scope('cross_entropy'):
        # The raw formulation of cross-entropy,
        #
        # tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(tf.softmax(y)),
        #                               reduction_indices=[1]))
        #
        # can be numerically unstable.
        #
        # So here we use tf.nn.softmax_cross_entropy_with_logits on the
        # raw outputs of the nn_layer above, and then average across
        # the batch.
        with tf.name_scope('total'):
            loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    tf.summary.scalar('cross_entropy', loss)

    
    #optimizer
    with tf.name_scope('train'):
        optimizer=tf.train.GradientDescentOptimizer(0.5).minimize(loss)
    
    #predictions for training
    train_prediction=tf.nn.softmax(logits)
    valid_prediction=tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, weights_1)+biases_1),weights_2)+biases_2)
    test_predicton= tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset,weights_1)+biases_1),weights_2)+biases_2)
    
    
   
    
   
    print(graph)
    print(sess)
# Out:
# <tensorflow.python.framework.ops.Graph object at 0x7f0e4bc5bb50>
# <tensorflow.python.client.session.InteractiveSession object at 0x7f0e4bc90350>

# %%
num_steps=30001


 

with tf.Session(graph=graph) as sess:
    # Merge all the summaries and write them out to /tmp/mnist_logs (by default)
    merged = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(log_dir + '/train',sess.graph)
    test_writer = tf.summary.FileWriter(log_dir + '/test')
    tf.global_variables_initializer().run()
    print("Initialized")
    c=0
    step_array=[]
    accuracy_array=[]
    
    for step in range(num_steps):
        #Pick an offset within taining data. which has been randomized.
        # Note: we could use better randomization across epochs
        offset= (step*batch_size) % (train_labels.shape[0] - batch_size) # we have used train_labels.shape[0] it is equal to the toatal no of image in the datasets
        
        #generate a minibatch , as SGD requires them
        batch_data= train_dataset[offset:(offset+batch_size),:]
        batch_labels= train_labels[offset:(offset+batch_size),:]
        
        #Prepare a dictionary telling the session where to feed the minibatch
        # The Key of the dictinary is the placeholder node of the graph to be fed,
        #and the value is the numpy array to feed to it.
        feed_dict={tf_train_dataset: batch_data,tf_train_labels: batch_labels}
        _,summary, l,predictions = sess.run( [optimizer,merged,loss, train_prediction], feed_dict=feed_dict)
        test_writer.add_summary(summary, step)
        
        if (step % 500==0):
            miniAccuracy=accuracy( valid_prediction.eval(), valid_labels)
            print("Minibatch loss at step %d: %f" % (step,l))
            print("Minibatch accurracy: %.1f%%" % miniAccuracy)
            print (c)
            step_array.append(step)
            accuracy_array.append(miniAccuracy)
            c=c+1
            plt.plot(step,miniAccuracy)
        print("Test Accuracy: %.1f%%" % accuracy(test_predicton.eval(),test_labels))
        
        ##print(accuracy(test_predicton.eval(),test_labels))
        
sess.close()
# Out:
# Initialized
# Minibatch loss at step 0: 318.348816
# Minibatch accurracy: 31.9%
# 0
# Test Accuracy: 34.0%
# Test Accuracy: 31.9%
# Test Accuracy: 44.7%
# Test Accuracy: 39.8%
# Test Accuracy: 52.4%
# Test Accuracy: 68.2%
# Test Accuracy: 78.5%
# Test Accuracy: 80.5%
# Test Accuracy: 81.2%
# Test Accuracy: 81.7%
# Test Accuracy: 80.9%
# Test Accuracy: 76.8%
# Test Accuracy: 78.8%
# Test Accuracy: 82.2%
# Test Accuracy: 82.7%
# Test Accuracy: 81.7%
# Test Accuracy: 79.5%
# Test Accuracy: 76.6%
# Test Accuracy: 74.9%
# Test Accuracy: 73.8%
# Test Accuracy: 81.5%

# Test Accuracy: 90.7%
# Test Accuracy: 90.8%
# Test Accuracy: 90.7%
# Test Accuracy: 90.7%
# Test Accuracy: 90.2%
# Test Accuracy: 90.3%
# Test Accuracy: 90.7%
# Test Accuracy: 91.0%
# Test Accuracy: 90.9%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 90.8%
# Test Accuracy: 90.8%
# Test Accuracy: 90.7%
# Test Accuracy: 90.8%
# Test Accuracy: 90.8%
# Test Accuracy: 90.5%
# Test Accuracy: 90.9%
# Test Accuracy: 90.9%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 90.3%
# Test Accuracy: 90.4%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 90.9%
# Test Accuracy: 90.9%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 89.4%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.0%
# Test Accuracy: 90.6%
# Test Accuracy: 90.7%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 88.9%
# Test Accuracy: 91.2%
# Test Accuracy: 90.8%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 90.8%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 90.8%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 89.1%
# Test Accuracy: 88.9%
# Test Accuracy: 90.9%
# Test Accuracy: 91.2%
# Test Accuracy: 90.5%
# Test Accuracy: 90.9%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.3%
# Test Accuracy: 89.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.5%
# Test Accuracy: 91.1%
# Test Accuracy: 91.7%
# Test Accuracy: 91.7%
# Test Accuracy: 91.5%
# Test Accuracy: 91.7%
# Test Accuracy: 91.6%
# Test Accuracy: 91.4%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 88.6%
# Test Accuracy: 91.1%
# Test Accuracy: 90.9%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 90.0%
# Test Accuracy: 90.5%
# Test Accuracy: 90.8%
# Test Accuracy: 91.4%
# Test Accuracy: 91.3%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 90.8%
# Test Accuracy: 88.7%
# Test Accuracy: 90.7%
# Test Accuracy: 90.6%
# Test Accuracy: 90.8%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 89.5%
# Test Accuracy: 88.7%
# Test Accuracy: 90.7%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.6%
# Test Accuracy: 91.7%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.2%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.2%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 89.1%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.6%
# Test Accuracy: 89.2%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 90.8%
# Test Accuracy: 90.9%
# Test Accuracy: 90.9%
# Test Accuracy: 90.7%
# Test Accuracy: 90.7%
# Test Accuracy: 90.8%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.2%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.7%
# Test Accuracy: 91.5%
# Test Accuracy: 91.7%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.6%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.7%
# Test Accuracy: 91.8%
# Test Accuracy: 91.8%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.8%
# Test Accuracy: 91.6%
# Test Accuracy: 91.4%
# Test Accuracy: 91.6%
# Test Accuracy: 91.9%
# Test Accuracy: 91.8%
# Test Accuracy: 91.7%
# Test Accuracy: 91.7%
# Test Accuracy: 91.7%
# Test Accuracy: 91.6%
# Test Accuracy: 91.6%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 90.9%
# Test Accuracy: 91.1%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 90.8%
# Test Accuracy: 90.8%
# Test Accuracy: 90.7%
# Minibatch loss at step 10000: 0.846478
# Minibatch accurracy: 84.2%
# 20
# Test Accuracy: 90.7%
# Test Accuracy: 90.9%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.3%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 90.8%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.6%
# Test Accuracy: 89.7%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.3%
# Test Accuracy: 90.7%
# Test Accuracy: 90.6%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 89.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.6%
# Test Accuracy: 91.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 89.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.3%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.1%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.4%
# Test Accuracy: 91.4%
# Test Accuracy: 91.5%
# Test Accuracy: 91.1%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.5%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 91.1%
# Test Accuracy: 91.5%
# Test Accuracy: 91.3%
# Test Accuracy: 91.2%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 89.0%
# Test Accuracy: 91.4%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 90.5%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 90.8%
# Test Accuracy: 88.8%
# Test Accuracy: 88.8%
# Test Accuracy: 90.9%
# Test Accuracy: 90.9%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.1%
# Test Accuracy: 91.2%
# Test Accuracy: 90.8%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 91.0%
# Test Accuracy: 88.7%
# Test Accuracy: 91.2%
# Test Accuracy: 91.4%
# Test Accuracy: 90.5%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 90.1%
# Test Accuracy: 90.8%
# Test Accuracy: 90.8%
# Test Accuracy: 90.9%
# Test Accuracy: 90.9%
# Test Accuracy: 91.2%
# Test Accuracy: 91.2%
# Test Accuracy: 91.1%
# Test Accuracy: 91.0%
# Test Accuracy: 90.8%
# Test Accuracy: 90.7%
# Test Accuracy: 90.7%
# Test Accuracy: 90.6%
# Test Accuracy: 90.6%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.0%
# Test Accuracy: 91.2%
# Test Accuracy: 89.3%
# Test Accuracy: 91.3%
# Test Accuracy: 91.1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-975ce735c75d> in <module>()
#      28         #and the value is the numpy array to feed to it.
#      29         feed_dict={tf_train_dataset: batch_data,tf_train_labels: batch_labels}
# ---> 30         _,summary, l,predictions = sess.run( [optimizer,merged,loss, train_prediction], feed_dict=feed_dict)
#      31         test_writer.add_summary(summary, step)
#      32
#
# /home/somanianurmahal/.conda/envs/eyeCon/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/somanianurmahal/.conda/envs/eyeCon/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/somanianurmahal/.conda/envs/eyeCon/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/somanianurmahal/.conda/envs/eyeCon/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/somanianurmahal/.conda/envs/eyeCon/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
